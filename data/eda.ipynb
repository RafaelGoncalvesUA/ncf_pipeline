# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
from plot import plot_ratings_count

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### MovieLens 25M Dataset
# - 1M for initial offline training
# - 24M for continual learning

# %%
data = pd.read_csv('ratings.csv')

# %%
data["userId"].nunique(), data["movieId"].nunique()
# Out:
# (162541, 59047)

# %%
data["rating"].mean()
# Out:
# 3.533854451353085

# %%
data["rating"].value_counts()
# Out:
# rating
# 4.0    6639798
# 3.0    4896928
# 5.0    3612474
# 3.5    3177318
# 4.5    2200539
# 2.0    1640868
# 2.5    1262797
# 1.0     776815
# 1.5     399490
# 0.5     393068
# Name: count, dtype: int64

# %%
plot_ratings_count(data, True)

# %%
data["userId"].value_counts().describe()
# Out:
# count    162541.000000
# mean        153.807932
# std         268.047590
# min          20.000000
# 25%          36.000000
# 50%          71.000000
# 75%         162.000000
# max       32202.000000
# Name: count, dtype: float64

# %%
data["movieId"].value_counts().describe()
# Out:
# count    59047.000000
# mean       423.393144
# std       2477.885821
# min          1.000000
# 25%          2.000000
# 50%          6.000000
# 75%         36.000000
# max      81491.000000
# Name: count, dtype: float64

# %% [markdown]
# ### MovieLens 1M Dataset
# For comparing our models with each other (hyperparameter tuning + k-fold cross-validation) and with the state-of-the-art models

# %%
data_1m = pd.read_csv('ratings_1m.csv')

# %%
data_1m["userId"].nunique(), data_1m["movieId"].nunique()
# Out:
# (6040, 3706)

# %%
data_1m["rating"].mean()
# Out:
# 3.581564453029317

# %%
plot_ratings_count(data_1m, scale=('K', 1000))
